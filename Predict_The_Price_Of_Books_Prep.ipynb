# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

# %%
dfr = pd.read_excel('Data_Train.xlsx')

# %%
dfs = pd.read_excel('Data_Test.xlsx')

# %%
dfr.head()
# Out:
#                                         Title           Author  \
# 0         The Prisoner's Gold (The Hunters 3)   Chris Kuzneski
# 1          Guru Dutt: A Tragedy in Three Acts     Arun Khopkar
# 2                Leviathan (Penguin Classics)    Thomas Hobbes
# 3          A Pocket Full of Rye (Miss Marple)  Agatha Christie
# 4  LIFE 70 Years of Extraordinary Photography  Editors of Life
#
#                    Edition             Reviews              Ratings  \
# 0  Paperback,– 10 Mar 2016  4.0 out of 5 stars   8 customer reviews
# 1   Paperback,– 7 Nov 2012  3.9 out of 5 stars  14 customer reviews
# 2  Paperback,– 25 Feb 1982  4.8 out of 5 stars   6 customer reviews
# 3   Paperback,– 5 Oct 2017  4.1 out of 5 stars  13 customer reviews
# 4  Hardcover,– 10 Oct 2006  5.0 out of 5 stars    1 customer review
#
#                                             Synopsis  \
# 0  THE HUNTERS return in their third brilliant no...
# 1  A layered portrait of a troubled genius for wh...
# ...

# %%
dfs.head()
# Out:
#                                                Title                  Author  \
# 0         The Complete Sherlock Holmes: 2 Boxes sets  Sir Arthur Conan Doyle
# 1  Learn Docker - Fundamentals of Docker 18.x: Ev...     Gabriel N. Schenker
# 2                                           Big Girl          Danielle Steel
# 3  Think Python: How to Think Like a Computer Sci...         Allen B. Downey
# 4  Oxford Word Skills: Advanced - Idioms & Phrasa...           Redman Gairns
#
#                               Edition             Reviews  \
# 0  Mass Market Paperback,– 1 Oct 1986  4.4 out of 5 stars
# 1     Paperback,– Import, 26 Apr 2018  5.0 out of 5 stars
# 2             Paperback,– 17 Mar 2011  5.0 out of 5 stars
# 3                    Paperback,– 2016  4.1 out of 5 stars
# 4             Paperback,– 26 Dec 2011  4.4 out of 5 stars
#
#                 Ratings                                           Synopsis  \
# ...

# %%
dfr.shape
# Out:
# (6237, 9)

# %%
dfs.shape
# Out:
# (1560, 8)

# %%
dfr.sample(3)
dfs.sample(3)
# Out:
#                                                  Title           Author  \
# 797                                  The Matlock Paper    Robert Ludlum
# 198                               Sad Cypress (Poirot)  Agatha Christie
# 521  ICC Cricket World Cup 2019 England & Wales 201...     Chris Hawkes
#
#                      Edition             Reviews              Ratings  \
# 797  Paperback,– 24 Aug 2005  4.0 out of 5 stars   2 customer reviews
# 198   Paperback,– 5 Oct 2017  4.6 out of 5 stars  29 customer reviews
# 521  Paperback,– 10 May 2019  3.5 out of 5 stars   7 customer reviews
#
#                                               Synopsis  \
# 797  James Barbour Matlock is a Vietnam veteran and...
# 198  An elderly stroke victim dies without having a...
# 521  Icc cricket world Cup England 2019: The offici...
#
#                                        Genre               BookCategory
# 797               Action & Adventure (Books)         Action & Adventure
# ...

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6237 entries, 0 to 6236
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         6237 non-null   object
#  1   Author        6237 non-null   object
#  2   Edition       6237 non-null   object
#  3   Reviews       6237 non-null   object
#  4   Ratings       6237 non-null   object
#  5   Synopsis      6237 non-null   object
#  6   Genre         6237 non-null   object
#  7   BookCategory  6237 non-null   object
#  8   Price         6237 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 438.7+ KB

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         1560 non-null   object
#  1   Author        1560 non-null   object
#  2   Edition       1560 non-null   object
#  3   Reviews       1560 non-null   object
#  4   Ratings       1560 non-null   object
#  5   Synopsis      1560 non-null   object
#  6   Genre         1560 non-null   object
#  7   BookCategory  1560 non-null   object
# dtypes: object(8)
# memory usage: 97.6+ KB

# %%
dfr.columns
# Out:
# Index(['Title', 'Author', 'Edition', 'Reviews', 'Ratings', 'Synopsis', 'Genre',
#        'BookCategory', 'Price'],
#       dtype='object')

# %%
dfr.describe()
# Out:
#               Price
# count   6237.000000
# mean     560.707516
# std      690.110657
# min       25.000000
# 25%      249.180000
# 50%      373.000000
# 75%      599.000000
# max    14100.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (9,4),dpi = 500)
plt.scatter(dfr['Price'],dfr['BookCategory'],marker = 'x',c = 'g')
plt.grid()

# %%
sns.boxplot(dfr['Price'])
# Out:
# <Axes: >

# %%
dfs.describe()
# Out:
#                                                 Title           Author  \
# count                                            1560             1560
# unique                                           1521             1224
# top     The Five Greatest Warriors (Jack West Series)  Agatha Christie
# freq                                                3               18
#
#                        Edition             Reviews            Ratings  \
# count                     1560                1560               1560
# unique                    1259                  30                163
# top     Paperback,– 5 Oct 2017  5.0 out of 5 stars  1 customer review
# freq                        12                 376                288
#
#                                                  Synopsis  \
# count                                                1560
# unique                                               1519
# top     The end is approaching ... Can Jack West unrav...
# ...

# %%
# dfr['Title'].value_counts()
# dfr.nunique()
#['Title', 'Author', 'Edition', 'Reviews', 'Ratings', 'Synopsis', 'Genre','BookCategory', 'Price']
dfr['BookCategory'].nunique()
# Out:
# 11

# %%
#['Title', 'Author', 'Edition', 'Reviews', 'Ratings', 'Synopsis', 'Genre','BookCategory', 'Price']
dfr['Author'].value_counts()
# Out:
# Agatha Christie      69
# Ladybird             49
# DK                   48
# Albert Uderzo        34
# Herge                34
#                      ..
# Bachi J. Karkaria     1
# Tim Wu                1
# Shruti                1
# E F Schumacher        1
# Stephenie Meyer       1
# Name: Author, Length: 3679, dtype: int64

# %%
dfr.sample(3)
# Out:
#                                                   Title  \
# 538   I See You: The Number One Sunday Times Bestsel...
# 1368  Kodaikanal :Vanishing Heritage of an Island in...
# 202       Surrender to the Highlander (Highland Brides)
#
#                                                  Author  \
# 538                                    Clare Mackintosh
# 1368  Pradeep Chakravarthy, Anil Choudhry, Jayashree...
# 202                                        Lynsay Sands
#
#                                           Edition             Reviews  \
# 538                       Paperback,– 16 May 2017  4.2 out of 5 stars
# 1368         Hardcover,– Illustrated, 24 Nov 2014  5.0 out of 5 stars
# 202   Mass Market Paperback,– Import, 30 Jan 2018  5.0 out of 5 stars
#
#                   Ratings                                           Synopsis  \
# 538   23 customer reviews  Don't miss the powerful and page-turning new n...
# ...

# %%
dfr['Synopsis'][2]
# Out:
# '"During the time men live without a common Power to keep them all in awe, they are in that condition which is called Warre"\n\nWritten during the turmoil of the English Civil War, Leviathan is an ambitious and highly original work of political philosophy. Claiming that man\'s essential nature is competitive and selfish, Hobbes formulates the case for a powerful sovereign—or "Leviathan"—to enforce peace and the law, substituting security for the anarchic freedom he believed human beings would otherwise experience. This worldview shocked many of Hobbes\'s contemporaries, and his work was publicly burnt for sedition and blasphemy when it was first published. But in his rejection of Aristotle\'s view of man as a naturally social being, and in his painstaking analysis of the ways in which society can and should function, Hobbes opened up a whole new world of political science.\n\nBased on the original 1651 text, this edition incorporates Hobbes\'s own corrections, while also retaining th
# ...

# %%
dfr.groupby(['BookCategory']).max('Price').sort_values('Price',ascending = False)
# Out:
#                                          Price
# BookCategory
# Comics & Mangas                       14100.00
# Politics                              13244.67
# Arts, Film & Photography              11715.12
# Romance                                9984.00
# Sports                                 7302.00
# Computing, Internet & Digital Media    5811.00
# Action & Adventure                     5600.00
# Language, Linguistics & Writing        5177.66
# Humour                                 4999.00
# Biographies, Diaries & True Accounts   2742.00
# Crime, Thriller & Mystery              2742.00

# %%
dfr.shape
# Out:
# (6231, 9)

# %%
# dfr.drop(dfr.loc[dfr['Price'] > 8000],axis = 1, inplace = True )

# %%
dfr.drop(dfr.index[[886, 2455, 2560, 2607, 2818, 4301]], axis = 0, inplace = True)

# %%
dfr.loc[dfr['Price'] > 8000]
# Out:
# Empty DataFrame
# Columns: [Title, Author, Edition, Reviews, Ratings, Synopsis, Genre, BookCategory, Price]
# Index: []

# %%
dfr.loc[dfr['Price'] > 8000].index
# Out:
# Int64Index([], dtype='int64')

# %%
dfr.loc[dfr['Price'] > 8000].count()
# Out:
# Title           0
# Author          0
# Edition         0
# Reviews         0
# Ratings         0
# Synopsis        0
# Genre           0
# BookCategory    0
# Price           0
# dtype: int64

# %%
dfr.groupby(['BookCategory']).count()
# Out:
#                                       Title  Author  Edition  Reviews  \
# BookCategory
# Action & Adventure                      818     818      818      818
# Arts, Film & Photography                515     515      515      515
# Biographies, Diaries & True Accounts    596     596      596      596
# Comics & Mangas                         581     581      581      581
# Computing, Internet & Digital Media     510     510      510      510
# Crime, Thriller & Mystery               723     723      723      723
# Humour                                  540     540      540      540
# Language, Linguistics & Writing         594     594      594      594
# Politics                                324     324      324      324
# Romance                                 559     559      559      559
# Sports                                  471     471      471      471
#
#                                       Ratings  Synopsis  Genre  Price
# BookCategory
# ...

# %%
dfr.sample()
# Out:
#               Author                 Edition             Reviews  \
# 2571  Scholastic Inc  Paperback,– 1 Jan 2014  4.6 out of 5 stars
#
#                  Ratings                                           Synopsis  \
# 2571  9 customer reviews  Grammar Builder is a series of 6 grammar pract...
#
#                      Genre                     BookCategory  Price
# 2571  Teaching & Education  Language, Linguistics & Writing  128.0

# %%
dfr.drop(['Title'],axis = 1,inplace = True)

# %%
dfr.drop(['Synopsis'],axis = 1,inplace = True)

# %%
dfr.drop(['Genre'],axis = 1,inplace = True)

# %%
dfs.drop(['Title'],axis = 1,inplace = True)

# %%
dfs.drop(['Synopsis'],axis = 1,inplace = True)

# %%
dfs.drop(['Genre'],axis = 1,inplace = True)

# %%
dfr.sample()
# Out:
#                 Author                  Edition             Reviews  \
# 2770  Simone Braverman  Paperback,– 26 May 2017  4.5 out of 5 stars
#
#                   Ratings                     BookCategory  Price
# 2770  24 customer reviews  Language, Linguistics & Writing  979.0

# %%
dfs.sample()
# Out:
#             Author                 Edition             Reviews  \
# 717  Bruno Vincent  Hardcover,– 3 Nov 2016  1.0 out of 5 stars
#
#                Ratings BookCategory
# 717  1 customer review       Humour

# %%
dfr.shape
# dfs.shape
# Out:
# (6231, 6)

# %%
dfr.dtypes
# Out:
# Author           object
# Edition          object
# Reviews          object
# Ratings          object
# BookCategory     object
# Price           float64
# dtype: object

# %%
dfr[['Rev', 'outof']] = dfr['Reviews'].str.split('out', expand=True)

# %%
dfs[['Rev', 'outof']] = dfs['Reviews'].str.split('out', expand=True)

# %%
dfs.drop(['Ratings'],axis = 1, inplace = True )

# %%
dfr.sample()
# Out:
#                  Author                 Edition             Reviews  \
# 23  Murugesan Ramaswamy  Paperback,– 1 Nov 2014  3.1 out of 5 stars
#
#                 Ratings                         BookCategory  Price   Rev  \
# 23  10 customer reviews  Computing, Internet & Digital Media  607.0  3.1
#
#           outof   BookType
# 23   of 5 stars  Paperback

# %%
dfs.sample()
# Out:
#             Author                              Edition             Reviews  \
# 1036  Nora Roberts  Mass Market Paperback,– 26 Jan 2010  5.0 out of 5 stars
#
#                 Ratings               BookCategory   Rev        outof
# 1036  1 customer review  Crime, Thriller & Mystery  5.0    of 5 stars

# %%
dfr.dtypes
# Out:
# Edition          object
# Reviews          object
# Ratings          object
# BookCategory     object
# Price           float64
# Rev              object
# outof            object
# dtype: object

# %%
dfr['BookType'] = dfr['Edition'].str.partition(sep=',', expand=True)[0]

# %%
dfr['Date'] = dfr['Edition'].str.partition(sep=',', expand=True)[2]

# %%
dfr['Year'] = dfr['Date'].str[-4:]

# %%
dfs['BookType'] = dfs['Edition'].str.partition(sep=',', expand=True)[0]

# %%
dfs['Date'] = dfs['Edition'].str.partition(sep=',', expand=True)[2]

# %%
dfs['Year'] = dfs['Date'].str[-4:]

# %%
dfr.sample()
# Out:
#            Author                 Edition             Reviews  \
# 4092  Mantak Chia  Paperback,– 9 Mar 2009  5.0 out of 5 stars
#
#                 Ratings BookCategory  Price   Rev        outof   BookType  \
# 4092  1 customer review       Sports  425.0  5.0    of 5 stars  Paperback
#
#               Date  Year  booktype  bookcateg
# 4092  – 9 Mar 2009  2009        12         10

# %%
dfs.sample()
# Out:
#            Author               Edition             Reviews  \
# 435  Unmukt Chand  Paperback,– Nov 2013  4.6 out of 5 stars
#
#                 Ratings BookCategory   Rev        outof   BookType  \
# 435  5 customer reviews       Sports  4.6    of 5 stars  Paperback
#
#            Date  Year  booktype  bookcateg
# 435  – Nov 2013  2013         6         10

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
# dfr['Title'].value_counts()
dfr.nunique()
# dfr['BookType'].unique()
# Out:
# Author          3676
# Edition         3367
# Reviews           36
# Ratings          342
# BookCategory      11
# Price           1608
# Rev               36
# outof              1
# BookType          18
# Date            2941
# Year              64
# booktype          18
# dtype: int64

# %%
dfr['booktype'] = le.fit_transform(dfr['BookType'])

# %%
dfs['booktype'] = le.fit_transform(dfs['BookType'])

# %%
dfs['BookType'].unique()
# Out:
# array(['Mass Market Paperback', 'Paperback', 'Hardcover', 'Cards',
#        'Sheet music', 'Flexibound', 'Spiral-bound', '(Chinese)',
#        'Loose Leaf'], dtype=object)

# %%
dfr['bookcateg'] = le.fit_transform(dfr['BookCategory'])

# %%
dfs['bookcateg'] = le.fit_transform(dfs['BookCategory'])

# %%
dfr.sample()
# Out:
#             Author                  Edition             Reviews  \
# 2650  Andre Agassi  Paperback,– 19 Aug 2010  4.7 out of 5 stars
#
#                    Ratings BookCategory  Price   Rev        outof   BookType  \
# 2650  167 customer reviews       Sports  277.0  4.7    of 5 stars  Paperback
#
#                Date  Year  booktype  bookcateg
# 2650  – 19 Aug 2010  2010        12         10

# %%
dfs.sample()
# Out:
#                Author                  Edition             Reviews  \
# 1489  Charles Bronson  Paperback,– 31 Jan 2007  4.5 out of 5 stars
#
#                  Ratings BookCategory   Rev        outof   BookType  \
# 1489  5 customer reviews       Sports  4.5    of 5 stars  Paperback
#
#                Date  Year  booktype  bookcateg
# 1489  – 31 Jan 2007  2007         6         10

# %%
dfs.to_excel('new_test.xlsx', index=False)

# %%
dfr.to_excel('new_train.xlsx', index=False)
